# %% [markdown]
# <a href="https://colab.research.google.com/github/yzhou359/MakeItTalk/blob/main/quick_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MakeItTalk Quick Demo (natural human face animation)
#
# - included project setup + pretrained model download
# - provides step-by-step details
# - todo: tdlr version

# %% [markdown]
# ## Preparations
# - Check GPU

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
import subprocess
print(subprocess.getoutput('nvidia-smi'))
# Out:
# ln: failed to create symbolic link '/usr/bin/nvidia-smi': Permission denied
# Wed Jun  9 15:45:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.73.01    Driver Version: 460.73.01    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 105...  Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   57C    P3    N/A /  N/A |    792MiB /  4042MiB |      5%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1145      G   /usr/lib/xorg/Xorg                 45MiB |
# |    0   N/A  N/A      1610      G   /usr/lib/xorg/Xorg                199MiB |
# |    0   N/A  N/A      1828      G   /usr/bin/gnome-shell              121MiB |
# |    0   N/A  N/A      2739      G   /usr/lib/firefox/firefox          417MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# - Check ffmpeg

# %%
print(subprocess.getoutput('ffmpeg'))
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1609680890771/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Hyper fast Audio and Video encoder
# usage: ffmpeg [options] [[infile options] -i infile]... {[outfile options] outfile}...
#
# Use -h to get full help or, even better, run 'man ffmpeg'

# %% [markdown]
# - Install Github https://github.com/yzhou359/MakeItTalk

# %%
# !git clone https://github.com/yzhou359/MakeItTalk
# Out:
# fatal: destination path 'MakeItTalk' already exists and is not an empty directory.

# %% [markdown]
# - Install requirements

# %%
# %cd MakeItTalk/
# !export PYTHONPATH=/content/MakeItTalk:$PYTHONPATH
# !pip install -r requirements.txt
# !pip install tensorboardX
# Out:
# [Errno 2] No such file or directory: 'MakeItTalk/'
# /home/faizan/cvit/MakeItTalk
# Requirement already satisfied: ffmpeg-python in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opencv-python in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (4.5.2.52)
# Collecting face_alignment
#   Downloading face_alignment-1.3.4.tar.gz (26 kB)
# Requirement already satisfied: scikit-learn in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.24.1)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pynormalize
#   Downloading pynormalize-0.1.4-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: soundfile in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.10.3.post1)
# Requirement already satisfied: librosa in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.8.0)
# Collecting pysptk
#   Downloading pysptk-0.1.18.tar.gz (419 kB)
#      |████████████████████████████████| 419 kB 1.5 MB/s eta 0:00:01
# Collecting pyworld
#   Downloading pyworld-0.3.0.tar.gz (212 kB)
#      |████████████████████████████████| 212 kB 2.6 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting resemblyzer
#   Downloading Resemblyzer-0.1.1.dev0-py3-none-any.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 309 kB/s eta 0:00:01
# Requirement already satisfied: torch in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from face_alignment->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: numpy in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from face_alignment->-r requirements.txt (line 3)) (1.20.3)
# Requirement already satisfied: scipy>=0.17 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from face_alignment->-r requirements.txt (line 3)) (1.6.2)
# Collecting scikit-image
#   Downloading scikit_image-0.18.1-cp39-cp39-manylinux1_x86_64.whl (28.9 MB)
#      |████████████████████████████████| 28.9 MB 2.2 kB/s eta 0:00:01
# Requirement already satisfied: tqdm in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from face_alignment->-r requirements.txt (line 3)) (4.60.0)
# Requirement already satisfied: numba in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from face_alignment->-r requirements.txt (line 3)) (0.53.1)
# Requirement already satisfied: future in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from ffmpeg-python->-r requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: pooch>=1.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: resampy>=0.2.2 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: decorator>=3.0.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: audioread>=2.0.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from librosa->-r requirements.txt (line 8)) (2.1.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from soundfile->-r requirements.txt (line 7)) (1.14.5)
# Requirement already satisfied: pycparser in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 7)) (2.20)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: setuptools in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (49.6.0.post20210108)
# Requirement already satisfied: appdirs in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: requests in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.25.1)
# Requirement already satisfied: packaging in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (20.9)
# Requirement already satisfied: six>=1.3 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from resampy>=0.2.2->librosa->-r requirements.txt (line 8)) (1.15.0)
# Collecting mutagen>=1.40.0
#   Downloading mutagen-1.45.1-py3-none-any.whl (218 kB)
#      |████████████████████████████████| 218 kB 4.8 MB/s eta 0:00:01
# Requirement already satisfied: cython>=0.24.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from pyworld->-r requirements.txt (line 10)) (0.29.23)
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 2.7 MB/s eta 0:00:01
# Collecting webrtcvad>=2.0.10
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      |████████████████████████████████| 66 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from packaging->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests->pooch>=1.0->librosa->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests->pooch>=1.0->librosa->-r requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2020.12.5)
# Collecting imageio>=2.3.0
#   Downloading imageio-2.9.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.6 MB/s eta 0:00:01
# Collecting networkx>=2.0
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 6.1 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.6.6-py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (8.1.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (3.3.4)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp39-cp39-manylinux1_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 10.0 kB/s ta 0:00:01     |███████████████████████████████▎| 4.2 MB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->face_alignment->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->face_alignment->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->face_alignment->-r requirements.txt (line 3)) (0.10.0)
# Building wheels for collected packages: face-alignment, pysptk, pyworld, webrtcvad, typing
#   Building wheel for face-alignment (setup.py) ... done
#   Created wheel for face-alignment: filename=face_alignment-1.3.4-py2.py3-none-any.whl size=27859 sha256=a5ee34397b5a5aaac34fd4dc5e54c05ec6ee4a0e802a019f295947a90aceb365
#   Stored in directory: /home/faizan/.cache/pip/wheels/c8/37/f2/704ed23ddf73315401dd6a03b83ec16a63651e544031359040
#   Building wheel for pysptk (setup.py) ... done
#   Created wheel for pysptk: filename=pysptk-0.1.18-cp39-cp39-linux_x86_64.whl size=428871 sha256=e15493c455d33cb518f13c449ff81dfbd5e798669d4aaa6f783839056757e53e
#   Stored in directory: /home/faizan/.cache/pip/wheels/e8/e1/cc/4a1d78b6665522d2b52783c94c9e0d22a61e3524f55dfa58ce
#   Building wheel for pyworld (PEP 517) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.0-cp39-cp39-linux_x86_64.whl size=206896 sha256=5753469e2770dbc2cff2aed7f4b7158673eb6cc367d1ef7784a4e1b9332923da
#   Stored in directory: /home/faizan/.cache/pip/wheels/a4/84/0e/28419b78625f2aebeba7f4e2714c114da8db2db7527dd166a9
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp39-cp39-linux_x86_64.whl size=27318 sha256=af2f543fff969c3a442cb7aebc59c57d262a2383dbfdb3972810438c7ee5b42a
#   Stored in directory: /home/faizan/.cache/pip/wheels/1f/fe/28/e8f0d5847ae2642b49fa974db1cea44d59ab59d0251c12f17b
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26308 sha256=4f5846466cbe12ec35c2a1a197a193174eede20e2e790b2e5e66df86daf04ba2
#   Stored in directory: /home/faizan/.cache/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
# Successfully built face-alignment pysptk pyworld webrtcvad typing
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, webrtcvad, typing, scikit-image, pydub, mutagen, resemblyzer, pyworld, pysptk, pynormalize, face-alignment
# Successfully installed PyWavelets-1.1.1 face-alignment-1.3.4 imageio-2.9.0 mutagen-1.45.1 networkx-2.5.1 pydub-0.25.1 pynormalize-0.1.4 pysptk-0.1.18 pyworld-0.3.0 resemblyzer-0.1.1.dev0 scikit-image-0.18.1 tifffile-2021.6.6 typing-3.7.4.3 webrtcvad-2.0.10
# Collecting tensorboardX
#   Downloading tensorboardX-2.2-py2.py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 1.2 MB/s eta 0:00:01
# Collecting protobuf>=3.8.0
#   Downloading protobuf-3.17.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from tensorboardX) (1.20.3)
# Requirement already satisfied: six>=1.9 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: protobuf, tensorboardX
# Successfully installed protobuf-3.17.3 tensorboardX-2.2

# %% [markdown]
# - Download pretrained models

# %%
# !mkdir examples/dump
# !mkdir examples/ckpt
# !pip install gdown
# !gdown -O examples/ckpt/ckpt_autovc.pth https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# !gdown -O examples/ckpt/ckpt_content_branch.pth https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# !gdown -O examples/ckpt/ckpt_speaker_branch.pth https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# !gdown -O examples/ckpt/ckpt_116_i2i_comb.pth https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# !gdown -O examples/dump/emb.pickle https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
# Out:
# Collecting gdown
#   Downloading gdown-3.13.0.tar.gz (9.3 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests[socks]>=2.12.0 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from gdown) (2.25.1)
# Requirement already satisfied: six in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from gdown) (1.15.0)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: tqdm in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from gdown) (4.60.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests[socks]>=2.12.0->gdown) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests[socks]>=2.12.0->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests[socks]>=2.12.0->gdown) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests[socks]>=2.12.0->gdown) (2020.12.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/faizan/miniconda3/envs/is/lib/python3.9/site-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.13.0-py3-none-any.whl size=9034 sha256=e2a56a71965f5e18d35f5bf8f6a14fe95244166d1284e35f9cb1b738a41938b9
#   Stored in directory: /home/faizan/.cache/pip/wheels/da/d4/e6/830f76664390501712f43e5e67bd4aaa8c72ae94dc6ebe55c6
# Successfully built gdown
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.0.12 gdown-3.13.0
# Downloading...
# From: https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# To: /home/faizan/cvit/MakeItTalk/examples/ckpt/ckpt_autovc.pth
# 172MB [00:21, 8.05MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# To: /home/faizan/cvit/MakeItTalk/examples/ckpt/ckpt_content_branch.pth
# 7.88MB [00:01, 6.30MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# To: /home/faizan/cvit/MakeItTalk/examples/ckpt/ckpt_speaker_branch.pth
# 15.4MB [00:01, 7.91MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# To: /home/faizan/cvit/MakeItTalk/examples/ckpt/ckpt_116_i2i_comb.pth
# 839MB [02:08, 6.53MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
# To: /home/faizan/cvit/MakeItTalk/examples/dump/emb.pickle
# 30.9MB [00:04, 7.11MB/s]

# %% [markdown]
# - prepare your images/audios (or you can use the existing ones)
#   - An image to animate: upload to `MakeItTalk/examples` folder, image size should be 256x256
#   - An audio (hopefully no noise) to talk: upload to `MakeItTalk/examples` folder as well
#
# ## Step 0: import necessary packages

# %%
import sys
sys.path.append("thirdparty/AdaptiveWingLoss")
import os, glob
import numpy as np
import cv2
import argparse
from src.approaches.train_image_translation import Image_translation_block
import torch
import pickle
import face_alignment
from src.autovc.AutoVC_mel_Convertor_retrain_version import AutoVC_mel_Convertor
import shutil
import time
import util.utils as util
from scipy.signal import savgol_filter
from src.approaches.train_audio2landmark import Audio2landmark_model

# %% [markdown]
# ## Step 1: Basic setup for the animation

# %%
default_head_name = 'paint_boy'           # the image name (with no .jpg) to animate
ADD_NAIVE_EYE = True                 # whether add naive eye blink
CLOSE_INPUT_FACE_MOUTH = False       # if your image has an opened mouth, put this as True, else False
AMP_LIP_SHAPE_X = 2.                 # amplify the lip motion in horizontal direction
AMP_LIP_SHAPE_Y = 2.                 # amplify the lip motion in vertical direction
AMP_HEAD_POSE_MOTION = 0.7           # amplify the head pose motion (usually smaller than 1.0, put it to 0. for a static head pose)

# %% [markdown]
# Default hyper-parameters for the model.

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--jpg', type=str, default='{}.jpg'.format(default_head_name))
parser.add_argument('--close_input_face_mouth', default=CLOSE_INPUT_FACE_MOUTH, action='store_true')

parser.add_argument('--load_AUTOVC_name', type=str, default='examples/ckpt/ckpt_autovc.pth')
parser.add_argument('--load_a2l_G_name', type=str, default='examples/ckpt/ckpt_speaker_branch.pth')
parser.add_argument('--load_a2l_C_name', type=str, default='examples/ckpt/ckpt_content_branch.pth') #ckpt_audio2landmark_c.pth')
parser.add_argument('--load_G_name', type=str, default='examples/ckpt/ckpt_116_i2i_comb.pth') #ckpt_image2image.pth') #ckpt_i2i_finetune_150.pth') #c

parser.add_argument('--amp_lip_x', type=float, default=AMP_LIP_SHAPE_X)
parser.add_argument('--amp_lip_y', type=float, default=AMP_LIP_SHAPE_Y)
parser.add_argument('--amp_pos', type=float, default=AMP_HEAD_POSE_MOTION)
parser.add_argument('--reuse_train_emb_list', type=str, nargs='+', default=[]) #  ['iWeklsXc0H8']) #['45hn7-LXDX8']) #['E_kmpT-EfOg']) #'iWeklsXc0H8', '29k8RtSUjE0', '45hn7-LXDX8',
parser.add_argument('--add_audio_in', default=False, action='store_true')
parser.add_argument('--comb_fan_awing', default=False, action='store_true')
parser.add_argument('--output_folder', type=str, default='examples')

parser.add_argument('--test_end2end', default=True, action='store_true')
parser.add_argument('--dump_dir', type=str, default='', help='')
parser.add_argument('--pos_dim', default=7, type=int)
parser.add_argument('--use_prior_net', default=True, action='store_true')
parser.add_argument('--transformer_d_model', default=32, type=int)
parser.add_argument('--transformer_N', default=2, type=int)
parser.add_argument('--transformer_heads', default=2, type=int)
parser.add_argument('--spk_emb_enc_size', default=16, type=int)
parser.add_argument('--init_content_encoder', type=str, default='')
parser.add_argument('--lr', type=float, default=1e-3, help='learning rate')
parser.add_argument('--reg_lr', type=float, default=1e-6, help='weight decay')
parser.add_argument('--write', default=False, action='store_true')
parser.add_argument('--segment_batch_size', type=int, default=1, help='batch size')
parser.add_argument('--emb_coef', default=3.0, type=float)
parser.add_argument('--lambda_laplacian_smooth_loss', default=1.0, type=float)
parser.add_argument('--use_11spk_only', default=False, action='store_true')
parser.add_argument('-f')

opt_parser = parser.parse_args()

# %% [markdown]
# ## Step 2: load the image and detect its landmark

# %%
img =cv2.imread('examples/' + opt_parser.jpg)
predictor = face_alignment.FaceAlignment(face_alignment.LandmarksType._3D, device='cpu', flip_input=True)
shapes = predictor.get_landmarks(img)
if (not shapes or len(shapes) != 1):
    print('Cannot detect face landmarks. Exit.')
    exit(-1)
shape_3d = shapes[0]

if(opt_parser.close_input_face_mouth):
    util.close_input_face_mouth(shape_3d)

# %% [markdown]
# ## (Optional) Simple manual adjustment to landmarks in case FAN is not accurate, e.g.
# - slimmer lips
# - wider eyes
# - wider mouth

# %%
shape_3d[48:, 0] = (shape_3d[48:, 0] - np.mean(shape_3d[48:, 0])) * 1.05 + np.mean(shape_3d[48:, 0]) # wider lips
shape_3d[49:54, 1] += 0.           # thinner upper lip
shape_3d[55:60, 1] -= 1.           # thinner lower lip
shape_3d[[37,38,43,44], 1] -=2.    # larger eyes
shape_3d[[40,41,46,47], 1] +=2.    # larger eyes

# %% [markdown]
# Normalize face as input to audio branch

# %%
shape_3d, scale, shift = util.norm_input_face(shape_3d)

# %% [markdown]
# ## Step 3: Generate input data for inference based on uploaded audio `MakeItTalk/examples/*.wav`

# %%
au_data = []
au_emb = []
ains = glob.glob1('examples', '*.wav')
ains = [item for item in ains if item is not 'tmp.wav']
ains.sort()
for ain in ains:
    os.system('ffmpeg -y -loglevel error -i examples/{} -ar 16000 examples/tmp.wav'.format(ain))
    shutil.copyfile('examples/tmp.wav', 'examples/{}'.format(ain))

    # au embedding
    from thirdparty.resemblyer_util.speaker_emb import get_spk_emb
    me, ae = get_spk_emb('examples/{}'.format(ain))
    au_emb.append(me.reshape(-1))

    print('Processing audio file', ain)
    c = AutoVC_mel_Convertor('examples')

    au_data_i = c.convert_single_wav_to_autovc_input(audio_filename=os.path.join('examples', ain),
           autovc_model_path=opt_parser.load_AUTOVC_name)
    au_data += au_data_i
if(os.path.isfile('examples/tmp.wav')):
    os.remove('examples/tmp.wav')

# landmark fake placeholder
fl_data = []
rot_tran, rot_quat, anchor_t_shape = [], [], []
for au, info in au_data:
    au_length = au.shape[0]
    fl = np.zeros(shape=(au_length, 68 * 3))
    fl_data.append((fl, info))
    rot_tran.append(np.zeros(shape=(au_length, 3, 4)))
    rot_quat.append(np.zeros(shape=(au_length, 4)))
    anchor_t_shape.append(np.zeros(shape=(au_length, 68 * 3)))

if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_au.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_au.pickle'))
if (os.path.exists(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))

with open(os.path.join('examples', 'dump', 'random_val_fl.pickle'), 'wb') as fp:
    pickle.dump(fl_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_au.pickle'), 'wb') as fp:
    pickle.dump(au_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_gaze.pickle'), 'wb') as fp:
    gaze = {'rot_trans':rot_tran, 'rot_quat':rot_quat, 'anchor_t_shape':anchor_t_shape}
    pickle.dump(gaze, fp)
# Out:
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-7-50fe2f4fa52c>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   ains = [item for item in ains if item is not 'tmp.wav']
# Loaded the voice encoder model on cuda in 21.36 seconds.
# Processing audio file M6_04_16k.wav
# 0 out of 0 are in this portion
# Loaded the voice encoder model on cuda in 0.01 seconds.
# source shape: torch.Size([1, 320, 80]) torch.Size([1, 256]) torch.Size([1, 256]) torch.Size([1, 320, 257])
# converted shape: torch.Size([1, 320, 80]) torch.Size([1, 640])

# %% [markdown]
# ## Step 4: Audio-to-Landmarks prediction

# %%
# !pwd
model = Audio2landmark_model(opt_parser, jpg_shape=shape_3d)
if(len(opt_parser.reuse_train_emb_list) == 0):
    model.test(au_emb=au_emb)
else:
    model.test(au_emb=None)
# Out:
# /home/faizan/cvit/MakeItTalk
# Run on device: cuda
# Loading Data random_val
# EVAL num videos: 1
# G: Running on cuda, total num params = 3.00M
# ======== LOAD PRETRAINED FACE ID MODEL examples/ckpt/ckpt_speaker_branch.pth =========
# ======== LOAD PRETRAINED FACE ID MODEL examples/ckpt/ckpt_content_branch.pth =========
# ====================================
# 48uYS3bHIA8
# YAZuSHvwVC0
# 0yaLdVk_UyQ
# E_kmpT-EfOg
# fQR31F7L3ww
# JPMZAOGGHh8
# W6uRNCJmdtI
# 2KL8PfQPmBg
# p575B7k07a8
# iUoAe2gXKE4
# HH-iOC056aQ
# S8fiWqrZEew
# ROWN2ssXek8
# irx71tYyI-Q
# me6cdZCM2FY
# OkqHtWOFliM
# OfPKHc6w2vw
# 1lh57VnuaKE
# _ldiVrXgZKc
# H1Xnb_rtgqY
# 45hn7-LXDX8
# bs7ZWVqAGCU
# UElg0R7fmlk
# bCs5SoifsiY
# 1Lx_ZqrK1bM
# RrnL6Pcjjbw
# sRbWv2R2hxE
# wJmdE0G4sEg
# hE-4e1vEiT8
# XXbxe3fCQqg
# 02HOKnTjBlQ
# wAAMEC1OsRc
# 7Sk--XzX8b0
# I5Lm0Qce5kg
# qLxfiUMYgQg
# _VpqWkdcaqM
# ljIkW4uVVQY
# 5m5iPZNJS6c
# J-NPsvtQ8lE
# gOrQyrbptGo
# 43BiUVlNy58
# swLghyvhoqA
# X3FCAoFnmdA
# 2NiCRAmwoc4
# KVUf0J2LAaA
# YtZS9hH1j24
# 5fZj9Fzi5K0
# wbWKG26ebMw
# QgNlXur0wrs
# qek_5m1MRik
# rmFsUV5ICKk
# bEdGv1wixF4
# ljh5PB6Utsc
# izudwWTXuUk
# B08yOvYMF7Y
# UEmI4r5G-5Y
# Scujgl9GbHA
# sxCbrYjBsGA
# qvQC0w3y_Fo
# bXpavyiCu10
# iWeklsXc0H8
# H00oAfd_GsM
# Z7WRt--g-h4
# 29k8RtSUjE0
# E0zgrhQ0QDw
# 9KhvSxKE6Mc
# qLNvRwMkhik
# ====================================
# /home/faizan/cvit/MakeItTalk/src/approaches/train_audio2landmark.py:98: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   z = torch.tensor(torch.zeros(aus.shape[0], 128), requires_grad=False, dtype=torch.float).to(device)
# examples/M6_04_16k.wav

# %% [markdown]
# ## Step 5: Natural face animation via Image-to-image translation

# %%
fls = glob.glob1('examples', 'pred_fls_*.txt')
fls.sort()

for i in range(0,len(fls)):
    fl = np.loadtxt(os.path.join('examples', fls[i])).reshape((-1, 68,3))
    fl[:, :, 0:2] = -fl[:, :, 0:2]
    fl[:, :, 0:2] = fl[:, :, 0:2] / scale - shift

    if (ADD_NAIVE_EYE):
        fl = util.add_naive_eye(fl)

    # additional smooth
    fl = fl.reshape((-1, 204))
    fl[:, :48 * 3] = savgol_filter(fl[:, :48 * 3], 15, 3, axis=0)
    fl[:, 48*3:] = savgol_filter(fl[:, 48*3:], 5, 3, axis=0)
    fl = fl.reshape((-1, 68, 3))

    ''' STEP 6: Imag2image translation '''
    model = Image_translation_block(opt_parser, single_test=True)
    with torch.no_grad():
        model.single_test(jpg=img, fls=fl, filename=fls[i], prefix=opt_parser.jpg.split('.')[0])
        print('finish image2image gen')
    os.remove(os.path.join('examples', fls[i]))
# Out:
# Run on device cuda
# Time - only video: 12.597930669784546
# Time - ffmpeg add audio: 13.770684242248535
# finish image2image gen

# %% [markdown]
# ## Visualize your animation!

# %%
from IPython.display import HTML
from base64 import b64encode

for ain in ains:
  OUTPUT_MP4_NAME = '{}_pred_fls_{}_audio_embed.mp4'.format(
    opt_parser.jpg.split('.')[0],
    ain.split('.')[0]
    )
  mp4 = open('examples/{}'.format(OUTPUT_MP4_NAME),'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

  print('Display animation: examples/{}'.format(OUTPUT_MP4_NAME))
  display(HTML("""
  <video width=600 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
# Out:
# Display animation: examples/paint_boy_pred_fls_M6_04_16k_audio_embed.mp4
#   <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
